# %% [markdown]
# Cognorise_Infotech_Project_Task2
#
# SHAHAMA VP

# %% [markdown]
# # **DIABETES PREDICTION**

# %% [markdown]
# **A MACHINE LEARNING PROJECT FOR PREDICT WHETHER A PERSON HAS DIABETES OR NOT**

# %%
# importing the sufficient python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# load the dataset
df=pd.read_csv('/content/drive/MyDrive/Cognorise Infotech/diabetes_prediction_dataset.csv')
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
# checking the number of rows and columns
df.shape
# Out:
# (100000, 9)

# %%
#Check the missing values
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
# to print column names of dataframe
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
# to print the datatype of each column
df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
# to get a concise summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %% [markdown]
# # **DATA VISUALIZATION**

# %%
# plotting the data distribution plots before removing null values
df.hist(figsize = (10,10),color='pink')
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'hypertension'}>,
#         <Axes: title={'center': 'heart_disease'}>],
#        [<Axes: title={'center': 'bmi'}>,
#         <Axes: title={'center': 'HbA1c_level'}>,
#         <Axes: title={'center': 'blood_glucose_level'}>],
#        [<Axes: title={'center': 'diabetes'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %%
# plotting the gender column in count plot
x=['female','male']
y=[58552,41430]
plt.bar(x,y,color='pink')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender VS Count')
plt.show()

# %% [markdown]
# # **Converting the text data to numerical values**

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['gender']=le.fit_transform(df['gender'])
df['smoking_history']=le.fit_transform(df['smoking_history'])
df
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1                4  25.19
# 1           0  54.0             0              0                0  27.32
# 2           1  28.0             0              0                4  27.32
# 3           0  36.0             0              0                1  23.45
# 4           1  76.0             1              1                1  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995       0  80.0             0              0                0  27.32
# 99996       0   2.0             0              0                0  17.37
# 99997       1  66.0             0              0                3  27.83
# 99998       0  24.0             0              0                4  35.42
# 99999       0  57.0             0              0                1  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# ...

# %%
# Correlation plot of the independent variables

plt.figure(figsize = (10, 8))
sns.heatmap(df.corr(), annot = True, fmt = ".3f", cmap = "YlGnBu")
plt.title("Correlation heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation heatmap')

# %%
# Exploring the density function plot of the Glucose levels

plt.figure(figsize = (10, 8))
kde = sns.kdeplot(df["blood_glucose_level"][df["diabetes"] == 1], palette = "crest", shade = True)
kde = sns.kdeplot(df["blood_glucose_level"][df["diabetes"] == 0], ax = kde, palette = "crest", shade= True)
kde.set_xlabel("Glucose Level")
kde.set_ylabel("Density")
kde.legend(["Positive Result","Negative Result"])

# %%
# Exploring the density function plot of the bmi

plt.figure(figsize = (10, 8))
kde = sns.kdeplot(df["bmi"][df["diabetes"] == 1],fill=True, common_norm=False, palette="crest", alpha=.5, linewidth=0,)
kde = sns.kdeplot(df["bmi"][df["diabetes"] == 0], ax = kde,fill=True, common_norm=False, palette="crest",alpha=.5, linewidth=0,)
kde.set_xlabel("Glucose Level")
kde.set_ylabel("Density")
kde.legend(["Positive Result","Negative Result"])

# %% [markdown]
# # **Separating features and Target**

# %%
# Assuming you have a 'Target' column that you want to predict
X = df.iloc[:,:-1]     # Features(Independent variable)
X
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1                4  25.19
# 1           0  54.0             0              0                0  27.32
# 2           1  28.0             0              0                4  27.32
# 3           0  36.0             0              0                1  23.45
# 4           1  76.0             1              1                1  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995       0  80.0             0              0                0  27.32
# 99996       0   2.0             0              0                0  17.37
# 99997       1  66.0             0              0                3  27.83
# 99998       0  24.0             0              0                4  35.42
# 99999       0  57.0             0              0                1  22.43
#
#        HbA1c_level  blood_glucose_level
# 0              6.6                  140
# ...

# %%
# Target variable
y= df.iloc[:,-1]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %% [markdown]
# # **Splitting the data into training data and Test data**

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# # **Build and Train Model**

# %%
# loading the model
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
rf=RandomForestClassifier(random_state=1)
knn=KNeighborsClassifier(n_neighbors=5)
ad=AdaBoostClassifier(random_state=1)
dt=DecisionTreeClassifier()

# %% [markdown]
# # **Make Predictions and Evaluate the Model**

# %%
# Make predictions on the test data
from sklearn.metrics import accuracy_score,classification_report
models=[rf,knn,ad,dt]
for model in models:
  print("****************************",model,"*************************************")
  model.fit(X_train,y_train)
  y_pred=model.predict(X_test)
  print('ACCURACY SCORE',accuracy_score(y_test,y_pred)*100)
  print(classification_report(y_test,y_pred))
# Out:
# **************************** RandomForestClassifier(random_state=1) *************************************
# ACCURACY SCORE 97.03
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     27422
#            1       0.95      0.69      0.80      2578
#
#     accuracy                           0.97     30000
#    macro avg       0.96      0.84      0.89     30000
# weighted avg       0.97      0.97      0.97     30000
#
# **************************** KNeighborsClassifier() *************************************
# ACCURACY SCORE 95.29333333333334
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     27422
#            1       0.87      0.53      0.66      2578
#
#     accuracy                           0.95     30000
#    macro avg       0.91      0.76      0.82     30000
# weighted avg       0.95      0.95      0.95     30000
#
# ...

# %%
from sklearn.metrics import ConfusionMatrixDisplay
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %% [markdown]
# # **Model Creation using Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
y_pred_lr=lr.predict(X_test)
y_pred_lr
# Out:
# array([ 0.09686366, -0.03882556,  0.10593956, ..., -0.00384568,
#         0.24900489,  0.12987686])

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
print('R2 SCORE',r2_score(y_test,y_pred_lr)*100)
print('MAE',mean_absolute_error(y_test,y_pred_lr))
print('MSE',mean_squared_error(y_test,y_pred_lr))
print('RMSE:',np.sqrt(mean_squared_error(y_test,y_pred_lr)))
# Out:
# R2 SCORE 35.14867255995788
# MAE 0.1541127994757248
# MSE 0.050939936605942586
# RMSE: 0.22569877404616664

# %%
x=['RF','KNN','AD','LR','DT']
y=[97.03,95.29,97.23,35.14,95.26]
plt.bar(x,y,color='pink')
plt.xlabel('Algorithm')
plt.ylabel('Score')
plt.title('Algorithm VS Score')
plt.show()

# %% [markdown]
# **from above evaluation Random Forest & Adaboost Classifier have best accuray score while  have Linear Regression worst accuracy**
